# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import zipfile
with zipfile.ZipFile("superstore.csv.zip", 'r') as zip_ref:
    zip_ref.extractall()

df = pd.read_csv("superstore.csv")

# %%
df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
# ...

# %%
df.shape
# Out:
# (51290, 27)

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', '记录数', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID',
#        'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
df.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row.ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# ...

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# 记录数               0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
df.nunique()
# Out:
# Category              3
# City               3636
# Country             147
# Customer.ID        4873
# Customer.Name       795
# Discount             27
# Market                7
# 记录数                   1
# Order.Date         1430
# Order.ID          25035
# Order.Priority        4
# Product.ID        10292
# Product.Name       3788
# Profit            24575
# Quantity             14
# Region               13
# Row.ID            51290
# Sales              2246
# Segment               3
# Ship.Date          1464
# Ship.Mode             4
# Shipping.Cost     16877
# State              1094
# Sub.Category         17
# Year                  4
# Market2               6
# weeknum              53
# dtype: int64

# %%
df.drop(columns=['记录数'],inplace=True)

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID',
#        'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
df[df['Profit']>1000].head(10)
# Out:
#              Category            City         Country Customer.ID  \
# 1757  Office Supplies        Columbia   United States   PW-192404
# 2143  Office Supplies         Atlanta   United States   CM-123854
# 2204  Office Supplies         Roswell   United States   DM-133454
# 2483  Office Supplies  Virginia Beach   United States   MW-182354
# 2722  Office Supplies     Minneapolis   United States   SC-200954
# 3027  Office Supplies         Midland   United States   SD-204854
# 3092  Office Supplies         Detroit   United States   AB-101054
# 3094  Office Supplies         Jackson   United States   AR-105404
# 3463  Office Supplies       Edinburgh  United Kingdom   LB-167952
# 4905  Office Supplies           Milan           Italy   QJ-192552
#
#              Customer.Name  Discount Market               Order.Date  \
# 1757          Pierre Wener       0.0     US  2012-02-21 00:00:00.000
# 2143  Christopher Martinez       0.0     US  2012-03-16 00:00:00.000
# ...

# %%
df.groupby(['Region','Category'])['Sales'].sum()
# Out:
# Region          Category
# Africa          Furniture           194650
#                 Office Supplies     266752
#                 Technology          322374
# Canada          Furniture            10595
#                 Office Supplies      30037
#                 Technology           26300
# Caribbean       Furniture           118379
#                 Office Supplies      89565
#                 Technology          116337
# Central         Furniture           860413
#                 Office Supplies     923471
#                 Technology         1038515
# Central Asia    Furniture           284369
#                 Office Supplies     162768
#                 Technology          305702
# EMEA            Furniture           228627
#                 Office Supplies     276712
#                 Technology          300845
# East            Furniture           208291
#                 Office Supplies     205549
#                 Technology          264994
# ...

# %%
df.groupby('Year')['Sales'].sum()
# Out:
# Year
# 2011    2259511
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: Sales, dtype: int64

# %%
df[['Sales','Profit','Discount']].corr()
# Out:
#              Sales    Profit  Discount
# Sales     1.000000  0.484923 -0.086728
# Profit    0.484923  1.000000 -0.316490
# Discount -0.086728 -0.316490  1.000000

# %%
df[['Customer.Name','Product.Name']].value_counts().head(10)
# Out:
# Customer.Name    Product.Name
# Cynthia Delaney  Staples                                    3
# Chad McGuire     Avery Binding Machine, Clear               3
# Herbert Flentye  Samsung Office Telephone, Full Size        3
# Alejandro Grove  Smead Removable Labels, Adjustable         3
# Brosina Hoffman  Logitech Numeric Keypad, Programmable      3
# Fred Wasserman   Novimex Shipping Labels, 5000 Label Set    3
# Filia McAdams    Cardinal Index Tab, Clear                  3
# Anthony Rawles   SanDisk Parchment Paper, Multicolor        3
# Lela Donovan     Jiffy Manila Envelope, Set of 50           3
# Maribeth Dona    Hon Chairmat, Red                          3
# Name: count, dtype: int64

# %%
df_num = df.select_dtypes(include='number')
df_num.head()
# Out:
#    Discount   Profit  Quantity  Row.ID  Sales  Shipping.Cost  Year  weeknum
# 0       0.0   9.3312         3   36624     19           4.37  2011        2
# 1       0.0   9.2928         2   37033     19           0.94  2011        4
# 2       0.0   9.8418         3   31468     21           1.81  2011       32
# 3       0.0  53.2608         2   31469    111           4.59  2011       32
# 4       0.0   3.1104         1   32440      6           1.32  2011       40

# %%
df_num.corr()
# Out:
#                Discount    Profit  Quantity    Row.ID     Sales  \
# Discount       1.000000 -0.316490 -0.019875  0.087594 -0.086728
# Profit        -0.316490  1.000000  0.104365 -0.019037  0.484923
# Quantity      -0.019875  0.104365  1.000000 -0.173483  0.313580
# Row.ID         0.087594 -0.019037 -0.173483  1.000000 -0.043888
# Sales         -0.086728  0.484923  0.313580 -0.043888  1.000000
# Shipping.Cost -0.079055  0.354441  0.272649 -0.039076  0.768075
# Year          -0.005894  0.002626 -0.005049 -0.000921 -0.002902
# weeknum       -0.000217 -0.000182  0.020839 -0.028776  0.001947
#
#                Shipping.Cost      Year   weeknum
# Discount           -0.079055 -0.005894 -0.000217
# Profit              0.354441  0.002626 -0.000182
# Quantity            0.272649 -0.005049  0.020839
# Row.ID             -0.039076 -0.000921 -0.028776
# Sales               0.768075 -0.002902  0.001947
# Shipping.Cost       1.000000 -0.003137  0.005347
# ...

# %%
np.corrcoef(df['Sales'],df['Profit'])
# Out:
# array([[1.       , 0.4849231],
#        [0.4849231, 1.       ]])

# %%
np.corrcoef(df['Discount'],df['Profit'])
# Out:
# array([[ 1.        , -0.31649017],
#        [-0.31649017,  1.        ]])

# %%
Sales = np.array(df['Sales'])
np.sum(Sales)
# Out:
# np.int64(12642905)

# %%
np.max(Sales)
# Out:
# np.int64(22638)

# %%
np.min(Sales)
# Out:
# np.int64(0)

# %%
np.std(Sales)
# Out:
# np.float64(487.5624215651816)

# %%
df_num.nunique()        #NUMerical unique data
# Out:
# Discount            27
# Profit           24575
# Quantity            14
# Row.ID           51290
# Sales             2246
# Shipping.Cost    16877
# Year                 4
# weeknum             53
# dtype: int64

# %%
cols = df_num.columns
cols
# Out:
# Index(['Discount', 'Profit', 'Quantity', 'Row.ID', 'Sales', 'Shipping.Cost',
#        'Year', 'weeknum'],
#       dtype='object')

# %%
for col in cols[2:]:
    print(df_num[col].value_counts())
# Out:
# Quantity
# 2     12748
# 3      9682
# 1      8963
# 4      6385
# 5      4882
# 6      3020
# 7      2385
# 8      1361
# 9       987
# 10      276
# 14      186
# 12      176
# 11      156
# 13       83
# Name: count, dtype: int64
# Row.ID
# 37371    1
# 36624    1
# 37033    1
# 31468    1
# 31469    1
#         ..
# 38657    1
# 32905    1
# 36111    1
# 31457    1
# 35241    1
# Name: count, Length: 51290, dtype: int64
# Sales
# 13      589
# 11      550
# 14      527
# 19      523
# 17      520
#        ...
# 3421      1
# 2760      1
# 2384      1
# 1721      1
# 3050      1
# Name: count, Length: 2246, dtype: int64
# Shipping.Cost
# 0.350    66
# 1.360    66
# 1.040    63
# 0.640    63
# 0.710    63
#          ..
# 1.716     1
# 0.925     1
# 2.253     1
# 1.285     1
# 2.147     1
# Name: count, Length: 16877, dtype: int64
# Year
# 2014    17531
# 2013    13799
# 2012    10962
# 2011     8998
# Name: count, dtype: int64
# weeknum
# 47    1527
# 46    1524
# 45    1508
# ...

# %%
df_cat = df.select_dtypes(include = 'object')
df_cat.head()                                        # Categorical DATA
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#   Market               Order.Date        Order.ID Order.Priority  \
# 0     US  2011-01-07 00:00:00.000  CA-2011-130813           High
# 1     US  2011-01-21 00:00:00.000  CA-2011-148614         Medium
# 2     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 3     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 4     US  2011-09-29 00:00:00.000  CA-2011-146969           High
#
#         Product.ID                                       Product.Name Region  \
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot = True,cmap ='Blues')
plt.show()

# %%
sns.pairplot(df_num)
plt.show()

# %%
sns.scatterplot(x='Sales',y='Profit',
               data=df)
plt.show()

# %%
sns.barplot(x='Category',y='Sales',data=df)
plt.show()

# %%
sns.histplot(df['Sales'], kde= True)
plt.show()

# %%
x=[0,1,2,3,4,5]
y=[0,1,2,6,8,11]

# %%
plt.figure(figsize = (10,5))
plt.grid(color = 'gray')
plt.plot(x,y, color = 'r' , marker = 'o')
plt.title("Sales Vs. Profit" , color = 'blue')
plt.xlabel("Profit")
plt.ylabel("Sales")
plt.show()

# %%
sns.boxplot(x='Category',y='Profit',data=df)
plt.show()         #Loss outliers shows

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Region',y = 'Profit',data=df)
plt.show()

# %%
plt.plot(df['Order.Date'], df['Sales'])
plt.xlabel('Order Date')
plt.ylabel('Sales')
plt.title('Sales Over Time')
plt.show()

# %%
print("Total Sales:", df['Sales'].sum())
print("Total Profit:", df['Profit'].sum())
print("Total Orders:", df['Order.ID'].nunique())
# Out:
# Total Sales: 12642905
# Total Profit: 1467457.2912800002
# Total Orders: 25035

# %%
df.to_csv("superstore.csv", index=False,sep=",")         #export CSV file

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\admin\python project

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '311_Service_Requests_from_2010_to_Present.csv', 'Customer service.ipynb', 'earthquake.ipynb', 'earthquake_data_tsunami.csv', 'Major Project.ipynb', 'Project.ipynb', 'Python file MYSQL Connector.ipynb', 'superstore.csv', 'superstore.csv.zip']

# %%
pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install cryptography
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install mysql-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
csv_files =[('superstore.csv','superstore')]

# %%
conn = mysql.connector.connect(host='localhost',
                               username='****',
                               password='*******',  
                               database='*********')

cursor = conn.cursor()
print("Connection established successfully")

# %%
folder_path = 'C:/Users/admin/python project'

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Prathmesh3364@localhost/superstore")
print("Connected Successfully")
# Out:
# Connected Successfully

# %%
df = pd.read_csv("superstore.csv")
df.to_sql("superstore",engine,if_exists = "replace",index=False)
# Out:
# 51290
